# %% [markdown]
# Apunts del curs, teoria i altres anotacions - _Pau Sampietro_

# %% [markdown]
# ## T4 - Logistic Regression

# %% [markdown]
# ### Logistic Regression Model

# %% [markdown]
# Model for a binary label Logistic regression:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Now, we have to set this two parameters learning from our data. This will be performed by using the **maximum-likelihood principle**:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Given that the Loss Function is **convex**, we will be solving it to find the optima by local search or with the procedure called **gradient descent** for logistic regression

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Logistic Regression in Use

# %% [markdown]
# Our goal is to take one sentence (review in Amazon, Yelp, etc), with an uncertain amount of words, and extract a binary label: `positive` or `negative`. To do it, we will be performing **Sentiment Analysis**

# %% [markdown]
# First of all, we have to convert every sentence in a vector (bag-of-words representation) counting every word as 1 apearance in the whole vocabulary, as follows:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# This vector is EXTREMELY sparse, since only contains few of the words of the whole vocabulary. Once runned the model, the words that affects more the predictions are the ones with the higher coeficient:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Also, the model drops an error of `21%`. Let's analyze the model:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
