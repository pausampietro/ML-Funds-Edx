# %% [markdown]
# Apunts del curs, teoria i altres anotacions - _Pau Sampietro_

# %% [markdown]
# ## T3 - More Generative Modelling

# %% [markdown]
# ### Other exponential families of Distributions

# %% [markdown]
# In 1 dimension, there are many distributions that could feat our data (1 feature), not only the Gaussian. Gamma family of distributions suits positive reals, Beta fits data within an interval of real numbers, Poisson works for integers and there are other distributions for categorical data.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Moving to higher dimension data, we have many options:

# %% [markdown]
# **1. Naive Bayes:** Assuming that the features are independent, and fitting one specific distribution for each feature, and then computing the global probability as follows:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# **2. Multivariate Gaussian:** Model correlations between features.

# %% [markdown]
# **3. Graphical Models:** Arbitrary dependencies between coordinates
