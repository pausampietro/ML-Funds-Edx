# %% [markdown]
# Apunts del curs, teoria i altres anotacions - _Pau Sampietro_

# %% [markdown]
# ## T3 - Multivariate Gaussian

# %% [markdown]
# ### Multivariate Gaussian in d-dimensions

# %% [markdown]
# To represent a multivariate Gaussian, we just extend the concepts of Bivariate Gaussian `mu`vector, `var(xi)` and `cov(xi,xj)` matrix, etc.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# To compute de Density, note that the `exp` term results in a **quadratic function** as seen before, with the form: $$ exp(-1/2 · x^T·M·x) $$

# %% [markdown]
# To define a multivariate Gaussian, we need **d^2 parameters**

# %% [markdown]
# ### Diagonal Gaussian: Independent Features

# %% [markdown]
# If all the features are independent, the covariance matrix results in a diagonal matrix with:
#
# $$ cov(x_i,x_j) = 0 $$
# for every `i,j`,
#
# And the countours of equal density are **axis-aligned** ellipsoids centered at `mu`. It results also in a simplyfied formula for calculating the density, as follows:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# To define a Diagonal Gaussian, we only need **2·d parameters**. This is the reason why diagonal gaussian is often used even when the features are not independent.

# %% [markdown]
# ### Spherical Gaussian: Special case

# %% [markdown]
# If all the features are independent, and in addition all the features have the same `variance`, then we can define a diagonal matrix as a multiple of the `Id` matrix (`var` times)

# %% [markdown]
# And the countours of equal density are **concentric spheres** centered at mu.The density, then, **only** depends on the distance from the point to the `mu`

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### How to fit a Gaussian to Data

# %% [markdown]
# To fit a Gaussian to data points (Xi as a d-dimension vector): $$ X_1,X_2,...,X_m $$

# %% [markdown]
# 1. Compute the _Empirical mean_:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 2. Compute the _Empirical covariance matrix_ with its i,j entries:

# %% [markdown]
# ![image.png](attachment:image.png)
